# %% [markdown]
# <a href="https://colab.research.google.com/github/Jay21-bot/Document-Text-Extraction/blob/main/Document_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf pdfplumber

# %%
from google.colab import files

# Upload the file
uploaded = files.upload()

# Get the path
for filename in uploaded:
    pdf_path = filename

print(f"📁 Uploaded File: {pdf_path}")
# Out:
#      <input type="file" id="files-3a7014c8-b2b8-4131-a367-e54c24f40933" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a7014c8-b2b8-4131-a367-e54c24f40933">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import fitz  # PyMuPDF
import pdfplumber
import json

data = {}
list_items = []

# Extract text using PyMuPDF
with fitz.open(pdf_path) as doc:
    for i, page in enumerate(doc):
        text = page.get_text().strip()
        if text:
            data[f"Page_{i+1}"] = text

# Extract tables using pdfplumber
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()
        for table in tables:
            if table:
                list_items.append(table)

# Add tables to data
data["List_items"] = list_items

# %%
from google.colab import files
import os
import fitz  # PyMuPDF
from docx import Document

ext = os.path.splitext(file_path)[1].lower()

text = ""

# PDF
if ext == ".pdf":
    with fitz.open(file_path) as doc:
        for i, page in enumerate(doc):
            text += f"\n--- Page {i+1} ---\n"
            text += page.get_text().strip()

# TXT
elif ext == ".txt":
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()

# DOCX
elif ext == ".docx":
    doc = Document(file_path)
    text = "\n".join([para.text for para in doc.paragraphs])

# Unsupported
else:
    text = "❌ Unsupported file type."

# Show extracted text
print("\n📄 Extracted Text:\n")
print(text if text else "(No text found)")
# Out:
# 📄 Extracted Text:
#
#
# --- Page 1 ---
# DevifyX Assignment
# LLM-Based Spreadsheet Formula Generator
# Assignment Deadline: 7 Days
# Assignment Submission Form:
# https://forms.gle/X1WcGHn3Jr25tzF26
# Objective
# Develop an intelligent application that leverages Large Language Models (LLMs) to con-
# vert natural language queries into accurate and contextually appropriate Excel or Google
# Sheets formulas. The solution should provide a user-friendly interface and robust backend
# capable of handling a variety of spreadsheet-related requests.
# Core Features
# 1. Natural Language Input: Accept free-form text queries from users describing
# the desired spreadsheet operation.
# 2. Formula Generation: Automatically generate correct Excel and/or Google Sheets
# formulas based on the user’s query.
# 3. Formula Explanation: Provide a human-readable explanation of the generated
# formula.
# 4. Support for Common Functions: Handle a wide range of spreadsheet functions
# ...
